# %% [markdown]
# # NETFLIX DATA ANALYSIS

# %% [markdown]
# TV's and MOVIES available on Netflix till 2021

# %%
#import the necessary library 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# %%
#readind the file
ntflx = pd.read_csv(r"C:\Users\BORN 2 CODE\Downloads\8. Netflix Dataset.csv")

# %%
ntflx.head(10)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
# 5      s6  TV Show     46        Serdar Akar
# 6      s7    Movie    122    Yasir Al Yasiri
# 7      s8    Movie    187     Kevin Reynolds
# 8      s9    Movie    706      Shravan Kumar
# 9     s10    Movie   1920       Vikram Bhatt
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
# ...

# %%
ntflx.tail(10)
# Out:
#      Show_Id Category                                    Title  \
# 7779   s7778  TV Show                              Zombie Dumb
# 7780   s7779    Movie                               Zombieland
# 7781   s7780  TV Show                                Zona Rosa
# 7782   s7781    Movie                                      Zoo
# 7783   s7782    Movie                                     Zoom
# 7784   s7783    Movie                                     Zozo
# 7785   s7784    Movie                                   Zubaan
# 7786   s7785    Movie                        Zulu Man in Japan
# 7787   s7786  TV Show                    Zumbo's Just Desserts
# 7788   s7787    Movie  ZZ TOP: THAT LITTLE OL' BAND FROM TEXAS
#
#              Director                                               Cast  \
# 7779              NaN                                                NaN
# 7780  Ruben Fleischer  Jesse Eisenberg, Woody Harrelson, Emma Stone, ...
# ...

# %%
ntflx.shape
# Out:
# (7789, 11)

# %%
# no. of elements 
ntflx.size
# Out:
# 85679

# %%
# colunns name
ntflx.columns
# Out:
# Index(['Show_Id', 'Category', 'Title', 'Director', 'Cast', 'Country',
#        'Release_Date', 'Rating', 'Duration', 'Type', 'Description'],
#       dtype='object')

# %%
ntflx.dtypes
# Out:
# Show_Id         object
# Category        object
# Title           object
# Director        object
# Cast            object
# Country         object
# Release_Date    object
# Rating          object
# Duration        object
# Type            object
# Description     object
# dtype: object

# %%
ntflx.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7789 entries, 0 to 7788
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Show_Id       7789 non-null   object
#  1   Category      7789 non-null   object
#  2   Title         7789 non-null   object
#  3   Director      5401 non-null   object
#  4   Cast          7071 non-null   object
#  5   Country       7282 non-null   object
#  6   Release_Date  7779 non-null   object
#  7   Rating        7782 non-null   object
#  8   Duration      7789 non-null   object
#  9   Type          7789 non-null   object
#  10  Description   7789 non-null   object
# dtypes: object(11)
# memory usage: 669.5+ KB

# %%
#chech the duplicate 
ntflx[ntflx.duplicated()]
# Out:
#      Show_Id Category              Title        Director  \
# 6300    s684    Movie           Backfire     Dave Patten
# 6622   s6621    Movie  The Lost Okoroshi  Abba T. Makama
#
#                                                    Cast        Country  \
# 6300  Black Deniro, Byron "Squally" Vinson, Dominic ...  United States
# 6622  Seun Ajayi, Judith Audu, Tope Tedela, Ifu Enna...        Nigeria
#
#            Release_Date Rating Duration  \
# 6300      April 5, 2019  TV-MA   97 min
# 6622  September 4, 2020  TV-MA   94 min
#
#                                        Type  \
# 6300  Dramas, Independent Movies, Thrillers
# 6622   Comedies, Dramas, Independent Movies
#
#                                             Description
# 6300  When two would-be robbers accidentally kill a ...
# 6622  A disillusioned security guard transforms into...

# %%
#drop the duplicated rows 
ntflx.drop_duplicates(inplace = True)

# %%
#after removing the duplicates rows 
ntflx.shape
# Out:
# (7787, 11)

# %%
#check the null values 
ntflx.isnull().sum()
# Out:
# Show_Id            0
# Category           0
# Title              0
# Director        2388
# Cast             718
# Country          507
# Release_Date      10
# Rating             7
# Duration           0
# Type               0
# Description        0
# dtype: int64

# %% [markdown]
# Insight :Here we have Director,Cast, Country,Release_Date,Rating having the null values

# %%
#We can see null values by using heatmap 
import seaborn as sns 
sns.heatmap(ntflx.isnull())
# Out:
# <AxesSubplot:>

# %%
#We can check any of the data from the data set ,example
ntflx[ntflx['Title'].isin(["Zoom"])]   # here Zoom is the name of movie
# Out:
#      Show_Id Category Title      Director  \
# 7783   s7782    Movie  Zoom  Peter Hewitt
#
#                                                    Cast        Country  \
# 7783  Tim Allen, Courteney Cox, Chevy Chase, Kate Ma...  United States
#
#           Release_Date Rating Duration                                Type  \
# 7783  January 11, 2020     PG   88 min  Children & Family Movies, Comedies
#
#                                             Description
# 7783  Dragged from civilian life, a former superhero...

# %%
#Create a new column of date time 

ntflx['Date_t'] = pd.to_datetime(ntflx['Release_Date'])

# %%
#chech the head (i.e to check the new column )
ntflx.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
#tv's and Movies yearwise 
ntflx['Date_t'].dt.year.value_counts()
# Out:
# 2019.0    2153
# 2020.0    2009
# 2018.0    1685
# 2017.0    1225
# 2016.0     443
# 2021.0     117
# 2015.0      88
# 2014.0      25
# 2011.0      13
# 2013.0      11
# 2012.0       3
# 2009.0       2
# 2008.0       2
# 2010.0       1
# Name: Date_t, dtype: int64

# %% [markdown]
# Insights : Here we can see 2019 has the highest no. of releasing shows
#     follwed by the 2020,2018 and so on.

# %%
#using Bar graph 
ntflx['Date_t'].dt.year.value_counts().plot(kind='bar')
# Out:
# <AxesSubplot:>

# %% [markdown]
# Yeah the graph shows amazing

# %%
#Here we have "Category" column ,here we acn see the counts of category 
ntflx.groupby('Category').Category.count()
# Out:
# Category
# Movie      5377
# TV Show    2410
# Name: Category, dtype: int64

# %%
#showing tv and movies using bar graph 
sns.countplot(ntflx['Category'])
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# <AxesSubplot:xlabel='Category', ylabel='count'>

# %%
#create a new column 'Year'
ntflx['Year'] = ntflx['Date_t'].dt.year

# %%
#cheaching the new created column 
ntflx.head()
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
# 4      s5    Movie     21     Robert Luketic
#
#                                                 Cast        Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...         Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
# 4  Jim Sturgess, Kevin Spacey, Kate Bosworth, Aar...  United States
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
# 3  November 16, 2017  PG-13     80 min
# 4    January 1, 2020  PG-13    123 min
#
# ...

# %%
# here we can check the movie(or tv) in any yeae
ntflx[ (ntflx['Category'] ==  'Movie') & (ntflx['Year'] == 2017)]
# Out:
#      Show_Id Category                              Title          Director  \
# 3         s4    Movie                                  9       Shane Acker
# 9        s10    Movie                               1920      Vikram Bhatt
# 10       s11    Movie                               1922      Zak Hilditch
# 33       s34    Movie                       #realityhigh  Fernando Lebrija
# 40       s41    Movie                        Çarsi Pazar   Muharrem Gülmez
# ...      ...      ...                                ...               ...
# 7725   s7724    Movie                       You Can Tutu       James Brown
# 7726   s7725    Movie          You Can’t Fight Christmas       Kenny Young
# 7731   s7730    Movie                         You Get Me   Brent Bonacorso
# 7763   s7762    Movie                             Zapped     Peter DeLuise
# 7774   s7773    Movie  Zipi & Zape y la Isla del Capitan      Oskar Santos
#
#                                                    Cast  \
# ...

# %%
#Now lets check the tv shows in india 
ntflx[ (ntflx['Category'] == 'TV Show') & (ntflx['Country'] == 'India')] ['Title']
# Out:
# 86            21 Sarfarosh: Saragarhi 1897
# 132                              7 (Seven)
# 340                           Agent Raghav
# 364                           Akbar Birbal
# 533                    Anjaan: Rural Myths
#                        ...
# 6249                  The Creative Indians
# 6400    The Golden Years with Javed Akhtar
# 6469                The House That Made Me
# 7294                            Typewriter
# 7705                       Yeh Meri Family
# Name: Title, Length: 71, dtype: object

# %%
# Now lets come to the Director column 
#here we check the top 5 directors 
ntflx['Director'].value_counts().head(5)
# Out:
# Raúl Campos, Jan Suter    18
# Marcus Raboy              16
# Jay Karas                 14
# Cathy Garcia-Molina       13
# Youssef Chahine           12
# Name: Director, dtype: int64

# %%
#now let check the type comedy movie
ntflx[ (ntflx['Category'] =='Movie') & (ntflx['Type']=='Comedies')]
# Out:
#      Show_Id Category                        Title                Director  \
# 33       s34    Movie                 #realityhigh        Fernando Lebrija
# 72       s73    Movie                     17 Again             Burr Steers
# 84       s85    Movie                    21 & Over  Jon Lucas, Scott Moore
# 148     s149    Movie         A Bad Moms Christmas  Jon Lucas, Scott Moore
# 174     s175    Movie  A Futile and Stupid Gesture              David Wain
# ...      ...      ...                          ...                     ...
# 7341   s7340    Movie         Undercover Brother 2            Leslie Small
# 7590   s7589    Movie            Where's the Money         Scott Zabielski
# 7623   s7622    Movie                    Wild Oats            Andy Tennant
# 7634   s7633    Movie                 Wine Country             Amy Poehler
# 7664   s7663    Movie                      Work It           Laura Terruso
#
#                                                    Cast  \
# ...

# %%
#Creating New Data -frame(by dropping the null values)
ntflx_new = ntflx.dropna()

# %%
#cheaking the new data 
ntflx_new.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
# 3      s4    Movie      9        Shane Acker
#
#                                                 Cast        Country  \
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...         Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...      Singapore
# 3  Elijah Wood, John C. Reilly, Jennifer Connelly...  United States
#
#         Release_Date Rating Duration  \
# 1  December 23, 2016  TV-MA   93 min
# 2  December 20, 2018      R   78 min
# 3  November 16, 2017  PG-13   80 min
#
#                                                 Type  \
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
# 3  Action & Adventure, Independent Movies, Sci-Fi...
#
#                                          Description     Date_t    Year
# ...

# %%
# lets check then "Shah Rukh Khan"(an indian actor) movies in Netflix 
ntflx_new[ntflx_new['Cast'].str.contains('Shah Rukh Khan')]
# Out:
#      Show_Id Category                        Title            Director  \
# 599     s600    Movie                        Asoka       Santosh Sivan
# 926     s927    Movie                        Billu        Priyadarshan
# 1257   s1258    Movie                      Chaahat        Mahesh Bhatt
# 1265   s1266    Movie                Chalte Chalte          Aziz Mirza
# 1267   s1268    Movie                    Chamatkar         Rajiv Mehra
# 1311   s1312    Movie              Chennai Express        Rohit Shetty
# 1667   s1668    Movie                 Dear Zindagi        Gauri Shinde
# 1760   s1761    Movie                       Dil Se         Mani Ratnam
# 1764   s1765    Movie                      Dilwale        Rohit Shetty
# 1807   s1808    Movie                          Don       Farhan Akhtar
# 1808   s1809    Movie                        Don 2       Farhan Akhtar
# 1896   s1897    Movie                    Duplicate        Mahesh Bhatt
# ...

# %%
#no. of Unique Ratings in Netflix
ntflx['Rating'].nunique()
# Out:
# 14

# %%
# what are the Unique Ratings 
ntflx['Rating'].unique()
# Out:
# array(['TV-MA', 'R', 'PG-13', 'TV-14', 'TV-PG', 'NR', 'TV-G', 'TV-Y', nan,
#        'TV-Y7', 'PG', 'G', 'NC-17', 'TV-Y7-FV', 'UR'], dtype=object)

# %%
plt.figure(figsize=(16,5))

sns.countplot(ntflx['Rating'])
plt.show()
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %% [markdown]
# Top 3 Ratings in Netflix are TV-MA,TV-14,TV-PG

# %%
#We can cheack any  Rating 
ntflx[(ntflx['Category']=='Movie') & (ntflx['Rating']=='TV-14') & (ntflx['Country']=='India')]
# Out:
#      Show_Id Category                     Title            Director  \
# 8         s9    Movie                       706       Shravan Kumar
# 18       s19    Movie                    15-Aug  Swapnaneel Jayakar
# 20       s21    Movie      ​​Kuch Bheege Alfaaz                Onir
# 21       s22    Movie              ​Goli Soda 2        Vijay Milton
# 22       s23    Movie        ​Maj Rati ​​Keteki   Santwana Bardoloi
# ...      ...      ...                       ...                 ...
# 7756   s7755    Movie                      Yuva         Mani Ratnam
# 7765   s7764    Movie                     Zenda      Avadhoot Gupte
# 7766   s7765    Movie                      Zero          Aanand Rai
# 7771   s7770    Movie  Zindagi Na Milegi Dobara         Zoya Akhtar
# 7785   s7784    Movie                    Zubaan         Mozez Singh
#
#                                                    Cast Country  \
# 8     Divya Dutta, Atul Kulkarni, Mohan Agashe, Anup...   India
# ...

# %%
ntflx[(ntflx['Category']=='TV Show') & (ntflx['Rating']=='R')]
# Out:
#      Show_Id Category                                Title           Director  \
# 4497   s4498  TV Show                                Nobel                NaN
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 4497  Aksel Hennie, Tuva Novotny, Anders Danielsen L...  Norway
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#            Release_Date Rating  Duration  \
# 4497  December 10, 2016      R  1 Season
# 6437     April 25, 2019      R  1 Season
#
#                                                  Type  \
# 4497  International TV Shows, TV Dramas, TV Thrillers
# 6437                                         TV Shows
#
#                                             Description     Date_t    Year
# 4497  A series of incidents in Afghanistan set compl... 2016-12-10  2016.0
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
ntflx[(ntflx['Category']=='TV Show') & (ntflx['Rating']=='R') & (ntflx['Year'] > 2017)]
# Out:
#      Show_Id Category                                Title           Director  \
# 6437   s6436  TV Show  The Hateful Eight: Extended Version  Quentin Tarantino
#
#                                                    Cast Country  \
# 6437  Samuel L. Jackson, Kurt Russell, Jennifer Jaso...     NaN
#
#         Release_Date Rating  Duration      Type  \
# 6437  April 25, 2019      R  1 Season  TV Shows
#
#                                             Description     Date_t    Year
# 6437  Trapped at a stagecoach stop as a storm rages ... 2019-04-25  2019.0

# %%
#now Duration 
ntflx.Duration.unique()
# Out:
# array(['4 Seasons', '93 min', '78 min', '80 min', '123 min', '1 Season',
#        '95 min', '119 min', '118 min', '143 min', '103 min', '89 min',
#        '91 min', '149 min', '144 min', '124 min', '87 min', '110 min',
#        '128 min', '117 min', '100 min', '2 Seasons', '84 min', '99 min',
#        '90 min', '102 min', '104 min', '105 min', '56 min', '125 min',
#        '81 min', '97 min', '106 min', '107 min', '109 min', '44 min',
#        '75 min', '101 min', '3 Seasons', '37 min', '113 min', '114 min',
#        '130 min', '94 min', '140 min', '135 min', '82 min', '70 min',
#        '121 min', '92 min', '164 min', '53 min', '83 min', '116 min',
#        '86 min', '120 min', '96 min', '126 min', '129 min', '77 min',
#        '137 min', '148 min', '28 min', '122 min', '176 min', '85 min',
#        '22 min', '68 min', '111 min', '29 min', '142 min', '168 min',
#        '21 min', '59 min', '20 min', '98 min', '108 min', '76 min',
# ...

# %% [markdown]
# Insight: Here we see some duration are in "min" and some Duration are in "Season"

# %%
#Here we only consider for the mins Duratio
ntflx.Duration.dtypes
# Out:
# dtype('O')

# %%
ntflx[['Minutes','Unit']] = ntflx['Duration'].str.split(' ', expand = True)

# %%
ntflx.head(3)
# Out:
#   Show_Id Category  Title           Director  \
# 0      s1  TV Show     3%                NaN
# 1      s2    Movie  07:19  Jorge Michel Grau
# 2      s3    Movie  23:59       Gilbert Chan
#
#                                                 Cast    Country  \
# 0  João Miguel, Bianca Comparato, Michel Gomes, R...     Brazil
# 1  Demián Bichir, Héctor Bonilla, Oscar Serrano, ...     Mexico
# 2  Tedd Chan, Stella Chung, Henley Hii, Lawrence ...  Singapore
#
#         Release_Date Rating   Duration  \
# 0    August 14, 2020  TV-MA  4 Seasons
# 1  December 23, 2016  TV-MA     93 min
# 2  December 20, 2018      R     78 min
#
#                                                 Type  \
# 0  International TV Shows, TV Dramas, TV Sci-Fi &...
# 1                       Dramas, International Movies
# 2                Horror Movies, International Movies
#
#                                          Description     Date_t    Year  \
# ...

# %%
ntflx['Minutes']
# Out:
# 0         4
# 1        93
# 2        78
# 3        80
# 4       123
#        ...
# 7784     99
# 7785    111
# 7786     44
# 7787      1
# 7788     90
# Name: Minutes, Length: 7787, dtype: object

# %%
ntflx.plot.scatter(x='Minutes', y='Year')
# Out:
# <AxesSubplot:xlabel='Minutes', ylabel='Year'>

# %%
#Types of Movies 
plt.figure(figsize=(20,5))

sns.countplot(ntflx['Type'])
plt.show()
# Out:
# C:\Users\BORN 2 CODE\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
